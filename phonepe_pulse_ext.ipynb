# %%
# !pip install GitPython

# %%
# Reference
# import os
# import pandas as pd
# import git
# import subprocess
# import csv
# import requests
# import json

# # # Phonpe Github repository Clone
# # os.system("git clone https://github.com/phonepe/pulse.git")

# # root_dir = (r'/content/pulse/data')

# # Clone the GitHub repository
# repo_url = "https://github.com/phonepe/pulse.git"
# repo_path = "D:\git_pro"
# if not os.path.exists(repo_path):
#     git.Repo.clone_from(repo_url, repo_path)

# # # Load and transform data
# # data = pd.read_csv(os.path.join(repo_path, "data.csv"))
# # Perform data cleaning and preprocessing using Pandas

# # # Save transformed data to CSV or JSON
# # transformed_data.to_csv("transformed_data.csv", index=False)

# %%
# import os

# os.environ['GIT_PYTHON_GIT_EXECUTABLE'] = 'D:\git_pro'
# os.environ['GIT_PYTHON_REFRESH'] = 'quiet'

# %%
import os
data_list = []
# Base path to the directory containing JSON files
base_directory = r"D:\git_pro\pulse\data\aggregated\transaction\country\india\state"

# Iterate through states
for state_folder in os.listdir(base_directory):
    state_path = os.path.join(base_directory, state_folder)
#     print(state)
    if os.path.isdir(state_path):
        # Iterate through years
        for year_folder in os.listdir(state_path):
            year_path = os.path.join(state_path, year_folder)
#             print(year_folder)
            if os.path.isdir(year_path):
                # Iterate through JSON files
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        json_file_path = os.path.join(year_path, json_file)
#                         print(json_file)
                        with open(json_file_path, 'r') as file:
                            data = json.load(file)
                            
                            # Extract the data we're interested in
                            for transaction_data in data['data']['transactionData']:
                                row_dict = {
                                    'States': state_folder,
                                    'Transaction_Year': year_folder,
                                    'Quarters': int(json_file.split('.')[0]),
                                    'Transaction_Type': transaction_data['name'],
                                    'Transaction_Count': transaction_data['paymentInstruments'][0]['count'],
                                    'Transaction_Amount': transaction_data['paymentInstruments'][0]['amount']
                                }
                                data_list.append(row_dict)

# %%
df1 = pd.DataFrame(data_list)

# %%
df1
# Out:
#                          States Transaction_Year  Quarters  \
# 0     andaman-&-nicobar-islands             2018         1
# 1     andaman-&-nicobar-islands             2018         1
# 2     andaman-&-nicobar-islands             2018         1
# 3     andaman-&-nicobar-islands             2018         1
# 4     andaman-&-nicobar-islands             2018         1
# ...                         ...              ...       ...
# 3949                west-bengal             2023         2
# 3950                west-bengal             2023         2
# 3951                west-bengal             2023         2
# 3952                west-bengal             2023         2
# 3953                west-bengal             2023         2
#
#               Transaction_Type  Transaction_Count  Transaction_Amount
# 0     Recharge & bill payments               4200        1.845307e+06
# 1        Peer-to-peer payments               1871        1.213866e+07
# ...

# %%
import os
import json

data_list2 = []
base_directory2 = r"D:\git_pro\pulse\data\aggregated\user\country\india\state"

for state_folder in os.listdir(base_directory2):
    state_path = os.path.join(base_directory2, state_folder)
    if os.path.isdir(state_path):
        for year_folder in os.listdir(state_path):
            year_path = os.path.join(state_path, year_folder)
            if os.path.isdir(year_path):
                aggregated_data = None  # Initialize aggregated_data variable
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        json_file_path = os.path.join(year_path, json_file)
                        with open(json_file_path, 'r') as file:
                            json_data = json.load(file)
                            if 'aggregated' in json_data['data']:
                                aggregated_data = json_data['data']['aggregated']
                        
                if aggregated_data:
                    row_dict = {
                        'States': state_folder,
                        'Transaction_Year': year_folder,
                        'Register_users': aggregated_data['registeredUsers'],
                        'App_opens': aggregated_data['appOpens']
                    }
                    data_list2.append(row_dict)

# %%
df2 = pd.DataFrame(data_list2)

# %%
df2
# Out:
#                         States Transaction_Year  Register_users  App_opens
# 0    andaman-&-nicobar-islands             2018           15222          0
# 1    andaman-&-nicobar-islands             2019           25960     177012
# 2    andaman-&-nicobar-islands             2020           52396     887208
# 3    andaman-&-nicobar-islands             2021           71780    2112910
# 4    andaman-&-nicobar-islands             2022           88442    4354093
# ..                         ...              ...             ...        ...
# 211                west-bengal             2019        10885058  244326613
# 212                west-bengal             2020        15662093  291721919
# 213                west-bengal             2021        20644527  512335839
# 214                west-bengal             2022        25536381  678066327
# 215                west-bengal             2023        27827662  350862668
#
# [216 rows x 4 columns]

# %%
import os
import json

data_list3 = []
base_directory3 = r"D:\git_pro\pulse\data\map\transaction\hover\country\india\state"

for state_folder in os.listdir(base_directory3):
    state_path = os.path.join(base_directory3, state_folder)
    if os.path.isdir(state_path):
        for year_folder in os.listdir(state_path):
            year_path = os.path.join(state_path, year_folder)
            if os.path.isdir(year_path):
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        json_file_path = os.path.join(year_path, json_file)
                        with open(json_file_path, 'r') as file:
                            json_data = json.load(file)
                            #print(json_data)
                        
                        for hoverDataList in json_data['data']['hoverDataList']:
                            row_dict = {'States': state_folder,
                                        'Transaction_Year': year_folder,
                                        'Quarters': int(json_file.split('.')[0]),
                                        'distric_name': hoverDataList['name'],
                                        'Transaction_Type': hoverDataList['metric'][0]['type'],
                                        'Transaction_Count': hoverDataList['metric'][0]['amount']
                                       }
                        data_list3.append(row_dict)

# %%
df3 = pd.DataFrame(data_list3)

# %%
df3
# Out:
#                         States Transaction_Year  Quarters        distric_name  \
# 0    andaman-&-nicobar-islands             2018         1   nicobars district
# 1    andaman-&-nicobar-islands             2018         2   nicobars district
# 2    andaman-&-nicobar-islands             2018         3   nicobars district
# 3    andaman-&-nicobar-islands             2018         4   nicobars district
# 4    andaman-&-nicobar-islands             2019         1   nicobars district
# ..                         ...              ...       ...                 ...
# 787                west-bengal             2022         2  darjiling district
# 788                west-bengal             2022         3  darjiling district
# 789                west-bengal             2022         4  darjiling district
# 790                west-bengal             2023         1  darjiling district
# 791                west-bengal             2023         2  darjiling district
#
# ...

# %%
import os
import json

data_list4 = []
base_directory4 = r"D:\git_pro\pulse\data\map\user\hover\country\india\state"

for state_folder in os.listdir(base_directory4):
    state_path = os.path.join(base_directory4, state_folder)
    if os.path.isdir(state_path):
        for year_folder in os.listdir(state_path):
            year_path = os.path.join(state_path, year_folder)
            if os.path.isdir(year_path):
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        json_file_path = os.path.join(year_path, json_file)
                        with open(json_file_path, 'r') as file:
                            json_data = json.load(file)
                            #print(json_data)
                        for district, values in json_data['data']['hoverData'].items():
                                row_dict = {
                                    'States': state_folder,
                                    'Transaction_Year': year_folder,
                                    'Quarter': int(json_file.split('.')[0]),
                                    'District': district,
                                    'RegisteredUsers': values['registeredUsers'],
                                }
                                data_list4.append(row_dict)

# %%
df4 = pd.DataFrame(data_list4)

# %%
df4
# Out:
#                           States Transaction_Year  Quarter  \
# 0      andaman-&-nicobar-islands             2018        1
# 1      andaman-&-nicobar-islands             2018        1
# 2      andaman-&-nicobar-islands             2018        1
# 3      andaman-&-nicobar-islands             2018        2
# 4      andaman-&-nicobar-islands             2018        2
# ...                          ...              ...      ...
# 16099                west-bengal             2023        2
# 16100                west-bengal             2023        2
# 16101                west-bengal             2023        2
# 16102                west-bengal             2023        2
# 16103                west-bengal             2023        2
#
#                                 District  RegisteredUsers
# 0      north and middle andaman district              632
# 1                 south andaman district             5846
# 2                      nicobars district              262
# ...

# %%
import os
data_list5 = []
# Base path to the directory containing JSON files
base_directory5 = r"D:\git_pro\pulse\data\top\transaction\country\india\state"

# Iterate through states
for state_folder in os.listdir(base_directory5):
    state_path = os.path.join(base_directory5, state_folder)
#     print(state)
    if os.path.isdir(state_path):
        # Iterate through years
        for year_folder in os.listdir(state_path):
            year_path = os.path.join(state_path, year_folder)
#             print(year_folder)
            if os.path.isdir(year_path):
                # Iterate through JSON files
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        json_file_path = os.path.join(year_path, json_file)
#                         print(json_file)
                        with open(json_file_path, 'r') as file:
                            data = json.load(file)
                            
                            # Extract the data we're interested in
                            for districts in data['data']['districts']:
                                row_dict = {
                                    'States': state_folder,
                                    'Transaction_Year': year_folder,
                                    'Quarters': int(json_file.split('.')[0]),
                                    'District': districts['entityName'],
                                    'Transaction_Type': districts['metric']['type'],
                                    'Transaction_Count': districts['metric']['count'],
                                    'Transaction_Amount': districts['metric']['amount']
                                }
                            data_list5.append(row_dict)

# %%
df5 = pd.DataFrame(data_list5)
df5
# Out:
#                         States Transaction_Year  Quarters  \
# 0    andaman-&-nicobar-islands             2018         1
# 1    andaman-&-nicobar-islands             2018         2
# 2    andaman-&-nicobar-islands             2018         3
# 3    andaman-&-nicobar-islands             2018         4
# 4    andaman-&-nicobar-islands             2019         1
# ..                         ...              ...       ...
# 787                west-bengal             2022         2
# 788                west-bengal             2022         3
# 789                west-bengal             2022         4
# 790                west-bengal             2023         1
# 791                west-bengal             2023         2
#
#                      District Transaction_Type  Transaction_Count  \
# 0    north and middle andaman            TOTAL                442
# 1    north and middle andaman            TOTAL                825
# 2    north and middle andaman            TOTAL               1283
# ...

# %%
import os
import json

data_list6 = []
data_list7 = []
base_directory6 = r"D:\git_pro\pulse\data\top\user\country\india\state"

for state_folder in os.listdir(base_directory6):
    state_path = os.path.join(base_directory6, state_folder)
    if os.path.isdir(state_path):
        for year_folder in os.listdir(state_path):
            year_path = os.path.join(state_path, year_folder)
            if os.path.isdir(year_path):
                for json_file in os.listdir(year_path):
                    if json_file.endswith('.json'):
                        json_file_path = os.path.join(year_path, json_file)
                        with open(json_file_path, 'r') as file:
                            data = json.load(file)
                            
                            for district in data['data']['districts']:
                                row_dict = {
                                    'States': state_folder,
                                    'Transaction_Year': year_folder,
                                    'Quarters': int(json_file.split('.')[0]),
                                    'District': district['name'],
                                    'RegisteredUsers': district['registeredUsers']
                                }
                            data_list6.append(row_dict)
                            
                            for pincode in data['data']['pincodes']:
                                row_dict = {
                                    'States': state_folder,
                                    'Transaction_Year': year_folder,
                                    'Quarters': int(json_file.split('.')[0]),
                                    'District_pin_code': pincode['name'],
                                    'RegisteredUsers_bypin_code': pincode['registeredUsers']
                                }
                            data_list7.append(row_dict)

# %%
df6 = pd.DataFrame(data_list6)
df6
# Out:
#                         States Transaction_Year  Quarters         District  \
# 0    andaman-&-nicobar-islands             2018         1         nicobars
# 1    andaman-&-nicobar-islands             2018         2         nicobars
# 2    andaman-&-nicobar-islands             2018         3         nicobars
# 3    andaman-&-nicobar-islands             2018         4         nicobars
# 4    andaman-&-nicobar-islands             2019         1         nicobars
# ..                         ...              ...       ...              ...
# 787                west-bengal             2022         2  purba bardhaman
# 788                west-bengal             2022         3  purba bardhaman
# 789                west-bengal             2022         4  purba bardhaman
# 790                west-bengal             2023         1  purba bardhaman
# 791                west-bengal             2023         2  purba bardhaman
#
#      RegisteredUsers
# 0                262
# 1                351
# ...

# %%
df7 = pd.DataFrame(data_list7)
df7
# Out:
#                         States Transaction_Year  Quarters District_pin_code  \
# 0    andaman-&-nicobar-islands             2018         1            744211
# 1    andaman-&-nicobar-islands             2018         2            744211
# 2    andaman-&-nicobar-islands             2018         3            744211
# 3    andaman-&-nicobar-islands             2018         4            744301
# 4    andaman-&-nicobar-islands             2019         1            744301
# ..                         ...              ...       ...               ...
# 787                west-bengal             2022         2            700150
# 788                west-bengal             2022         3            700150
# 789                west-bengal             2022         4            700150
# 790                west-bengal             2023         1            700150
# 791                west-bengal             2023         2            700091
#
#      RegisteredUsers_bypin_code
# ...

# %%
d1 = df1.drop_duplicates()
d2 = df2.drop_duplicates()
d3 = df3.drop_duplicates()
d4 = df4.drop_duplicates()
d5 = df5.drop_duplicates()
d6 = df6.drop_duplicates()
d7 = df6.drop_duplicates()

# %%
d2
# Out:
#                         States Transaction_Year  Register_users  App_opens
# 0    andaman-&-nicobar-islands             2018           15222          0
# 1    andaman-&-nicobar-islands             2019           25960     177012
# 2    andaman-&-nicobar-islands             2020           52396     887208
# 3    andaman-&-nicobar-islands             2021           71780    2112910
# 4    andaman-&-nicobar-islands             2022           88442    4354093
# ..                         ...              ...             ...        ...
# 211                west-bengal             2019        10885058  244326613
# 212                west-bengal             2020        15662093  291721919
# 213                west-bengal             2021        20644527  512335839
# 214                west-bengal             2022        25536381  678066327
# 215                west-bengal             2023        27827662  350862668
#
# [216 rows x 4 columns]

# %%
#checking Null values
null_counts = d1.isnull().sum()
print(null_counts)

null_counts = d2.isnull().sum()
print(null_counts)

null_counts = d3.isnull().sum()
print(null_counts)

null_counts = d4.isnull().sum()
print(null_counts)

null_counts = d5.isnull().sum()
print(null_counts)

null_counts = d6.isnull().sum()
print(null_counts)

null_counts = d7.isnull().sum()
print(null_counts)
# Out:
# States                0
# Transaction_Year      0
# Quarters              0
# Transaction_Type      0
# Transaction_Count     0
# Transaction_Amount    0
# dtype: int64
# States              0
# Transaction_Year    0
# Register_users      0
# App_opens           0
# dtype: int64
# States               0
# Transaction_Year     0
# Quarters             0
# distric_name         0
# Transaction_Type     0
# Transaction_Count    0
# dtype: int64
# States              0
# Transaction_Year    0
# Quarter             0
# District            0
# RegisteredUsers     0
# dtype: int64
# States                0
# Transaction_Year      0
# Quarters              0
# District              0
# Transaction_Type      0
# Transaction_Count     0
# Transaction_Amount    0
# dtype: int64
# States              0
# Transaction_Year    0
# Quarters            0
# District            0
# RegisteredUsers     0
# dtype: int64
# States              0
# Transaction_Year    0
# Quarters            0
# ...

# %%
def csv_data(data_df,name):
    output_path = r'D:\git_pro'+'\\'+name+'.csv'
    data_df.to_csv(output_path, index=False)

# %%
csv_data(d1,'Aggregated_transaction')

# %%
csv_data(d2,'Aggregated_user')
csv_data(d3,'Map_transaction')
csv_data(d4,'Map_user')
csv_data(d5,'Top_transaction')
csv_data(d6,'Top_district_name_user')
csv_data(d7,'Top_pin_code_user')

# %%
pip install pandas mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
d1
# Out:
#                          States Transaction_Year  Quarters  \
# 0     andaman-&-nicobar-islands             2018         1
# 1     andaman-&-nicobar-islands             2018         1
# 2     andaman-&-nicobar-islands             2018         1
# 3     andaman-&-nicobar-islands             2018         1
# 4     andaman-&-nicobar-islands             2018         1
# ...                         ...              ...       ...
# 3949                west-bengal             2023         2
# 3950                west-bengal             2023         2
# 3951                west-bengal             2023         2
# 3952                west-bengal             2023         2
# 3953                west-bengal             2023         2
#
#               Transaction_Type  Transaction_Count  Transaction_Amount
# 0     Recharge & bill payments               4200        1.845307e+06
# 1        Peer-to-peer payments               1871        1.213866e+07
# ...

# %%
import pandas as pd
import mysql.connector as sql

# %%
# !pip install sqlalchemy

# %%
# mydb = sql.connect(host="localhost",
#                    user="root",
#                    password="",
#                    database="phone_pe"
#                    )
# mycursor = mydb.cursor(buffered=True)

# %%
import pandas as pd
from sqlalchemy import create_engine
db_connection_str = 'mysql+mysqlconnector://root:@localhost/phone_pe'
db_connection = create_engine(db_connection_str)

# %%
table_name1 = 'Aggregated_transaction'
d1.to_sql(table_name1, con=db_connection, if_exists='replace', index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:1666: UserWarning: The provided table name 'Aggregated_transaction' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# -1

# %%
table_name1 = 'Aggregated_transaction'
d1.to_sql(table_name1, con=mydb, if_exists='replace', index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2022         try:
# -> 2023             cur.execute(*args, **kwargs)
#    2024             return cur
#
# ~\AppData\Roaming\Python\Python39\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     601                 if psub.remaining != 0:
# --> 602                     raise ProgrammingError(
#     603                         "Not all parameters were used in the SQL statement"
#
# ...

# %%
table_name2 = 'Aggregated_user'
d2.to_sql(table_name2, con=db_connection, if_exists='replace', index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:1666: UserWarning: The provided table name 'Aggregated_user' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# -1

# %%
table_name3 = 'Map_transaction'
d3.to_sql(table_name3, con=db_connection, if_exists='replace', index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:1666: UserWarning: The provided table name 'Map_transaction' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# -1

# %%
table_name4 = 'Map_user'
d4.to_sql(table_name4, con=db_connection, if_exists='replace', index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:1666: UserWarning: The provided table name 'Map_user' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# -1

# %%
table_name5 = 'top_transaction'
d5.to_sql(table_name5, con=db_connection, if_exists='replace', index=False)
# Out:
# -1

# %%
table_name6 = 'top_district_name_user'
d6.to_sql(table_name6, con=db_connection, if_exists='replace', index=False)
# Out:
# -1

# %%
table_name7 = 'Map_pin_code_user'
d7.to_sql(table_name7, con=db_connection, if_exists='replace', index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:1666: UserWarning: The provided table name 'Map_pin_code_user' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# -1

# %%
# scrap data

# %%
# import os
# data_list2 = []
# # Base path to the directory containing JSON files
# base_directory2 = r"D:\git_pro\pulse\data\aggregated\user\country\india\state"

# # Iterate through states
# for state_folder in os.listdir(base_directory2):
#     state_path = os.path.join(base_directory2, state_folder)
# #     print(state)
#     if os.path.isdir(state_path):
#         # Iterate through years
#         for year_folder in os.listdir(state_path):
#             year_path = os.path.join(state_path, year_folder)
# #             print(year_folder)
#             if os.path.isdir(year_path):
#                 # Iterate through JSON files
#                 for json_file in os.listdir(year_path):
#                     if json_file.endswith('.json'):
#                         json_file_path = os.path.join(year_path, json_file)
# #                         print(json_file)
#                         with open(json_file_path, 'r') as file:
#                             data2 = json.load(file)          
#                 for user_data in data2['data']['aggregated']:
#                     row_dict = {'States': state_folder,
#                                 'Transaction_Year': year_folder,
#                                 'Quarters': int(json_file.split('.')[0]),
#                                 'Register_users': user_data['registeredUsers'],
#                                 'App_opens': user_data['appopens']
#                                 }
# #                             for i in(data2['data']['aggregated']):
# #                                 print(i)
# #                                 break
# # #                                                                    data_list2.append(row_dict)
                            
                                    
# import os
# import json

# data_list2 = []
# base_directory2 = r"D:\git_pro\pulse\data\aggregated\user\country\india\state"

# for state_folder in os.listdir(base_directory2):
#     state_path = os.path.join(base_directory2, state_folder)
#     if os.path.isdir(state_path):
#         for year_folder in os.listdir(state_path):
#             year_path = os.path.join(state_path, year_folder)
#             if os.path.isdir(year_path):
#                 for json_file in os.listdir(year_path):
#                     if json_file.endswith('.json'):
#                         json_file_path = os.path.join(year_path, json_file)
#                         with open(json_file_path, 'r') as file:
#                             data2 = json.load(file)
#                         print(data2)
#                         for user_data in data2['data']:
#                             row_dict = {
#                                 'States': state_folder,
#                                 'Transaction_Year': year_folder,
#                                 'Quarters': int(json_file.split('.')[0]),
#                                 'Register_users': user_data['aggregated']['registeredUsers'],
#                                 'App_opens': user_data['aggregated']['appopens']
#                             }
#                             data_list2.append(row_dict)
# import os
# data_list6 = []
# # Base path to the directory containing JSON files
# base_directory6 = r"D:\git_pro\pulse\data\top\user\country\india\state"

# # Iterate through states
# for state_folder in os.listdir(base_directory6):
#     state_path = os.path.join(base_directory6, state_folder)
# #     print(state)
#     if os.path.isdir(state_path):
#         # Iterate through years
#         for year_folder in os.listdir(state_path):
#             year_path = os.path.join(state_path, year_folder)
# #             print(year_folder)
#             if os.path.isdir(year_path):
#                 # Iterate through JSON files
#                 for json_file in os.listdir(year_path):
#                     if json_file.endswith('.json'):
#                         json_file_path = os.path.join(year_path, json_file)
# #                         print(json_file)
#                         with open(json_file_path, 'r') as file:
#                             data = json.load(file)
#                             print(data)
                            
#                             # Extract the data we're interested in
#                             for districts in data['data']['districts']:
#                                 row_dict = {'States': state_folder,
#                                             'Transaction_Year': year_folder,
#                                             'Quarters': int(json_file.split('.')[0]),
#                                             'District': district['name']if 'name' in district else district['pincode'],
#                                             'RegisteredUsers': district['registeredUsers']
#                                            }
#                             data_list6.append(row_dict)
